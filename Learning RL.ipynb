# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
#   Using cached stable_baselines3-1.6.0-py3-none-any.whl (177 kB)
# Requirement already satisfied: matplotlib in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: numpy in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.6)
# Collecting torch>=1.11
#   Using cached torch-1.12.1-cp37-cp37m-win_amd64.whl (161.9 MB)
# Collecting gym==0.21
#   Using cached gym-0.21.0.tar.gz (1.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.3.5)
# Requirement already satisfied: cloudpickle in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pillow in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.2.0)
# Collecting protobuf~=3.19.0
#   Using cached protobuf-3.19.4-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      --------------------------------------- 35.6/35.6 MB 10.5 MB/s eta 0:00:00
# Collecting tensorboard>=2.2.0
#   Using cached tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
# Collecting autorom[accept-rom-license]~=0.4.2
#   Using cached AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: psutil in c:\users\turbo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Collecting ale-py==0.7.4
#   Using cached ale_py-0.7.4-cp37-cp37m-win_amd64.whl (904 kB)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\turbo\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: importlib-resources in c:\users\turbo\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: tqdm in c:\users\turbo\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: requests in c:\users\turbo\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: click in c:\users\turbo\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Collecting AutoROM.accept-rom-license
#   Using cached AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\turbo\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.3)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\turbo\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\turbo\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (61.2.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.47.0-cp37-cp37m-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 11.9 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.10.0-py2.py3-none-any.whl (167 kB)
# Requirement already satisfied: typing-extensions in c:\users\turbo\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\turbo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\turbo\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\turbo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\turbo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\turbo\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4->stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\turbo\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\turbo\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\turbo\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\turbo\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.11)
# Requirement already satisfied: colorama in c:\users\turbo\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\turbo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Building wheels for collected packages: gym, AutoROM.accept-rom-license
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616825 sha256=15e8dfdeccf62e55da0d3111a75b958b23a93ebd644729218edd3ddad5e9c196
#   Stored in directory: c:\users\turbo\appdata\local\pip\cache\wheels\76\ee\9c\36bfe3e079df99acf5ae57f4e3464ff2771b34447d6d2f2148
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): started
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=446447 sha256=feaa05e0fe4ebd394a9eebbbe35cd7830a0d932a645c75ab962f6ad062780e64
#   Stored in directory: c:\users\turbo\appdata\local\pip\cache\wheels\87\67\2e\6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built gym AutoROM.accept-rom-license
# Installing collected packages: tensorboard-plugin-wit, torch, tensorboard-data-server, rsa, protobuf, opencv-python, oauthlib, grpcio, cachetools, absl-py, requests-oauthlib, markdown, gym, google-auth, ale-py, stable-baselines3, google-auth-oauthlib, AutoROM.accept-rom-license, autorom, tensorboard
# Successfully installed AutoROM.accept-rom-license-0.4.2 absl-py-1.2.0 ale-py-0.7.4 autorom-0.4.2 cachetools-5.2.0 google-auth-2.10.0 google-auth-oauthlib-0.4.6 grpcio-1.47.0 gym-0.21.0 markdown-3.4.1 oauthlib-3.2.0 opencv-python-4.6.0.66 protobuf-3.19.4 requests-oauthlib-1.3.1 rsa-4.9 stable-baselines3-1.6.0 tensorboard-2.10.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 torch-1.12.1

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:21.0
# Episode:2 Score:12.0
# Episode:3 Score:32.0
# Episode:4 Score:14.0
# Episode:5 Score:16.0

# %%
pip install gym[all]
# Out:
# Requirement already satisfied: gym[all] in c:\users\turbo\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (1.21.6)
# Requirement already satisfied: importlib-metadata>=4.8.1 in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (4.11.3)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scipy>=1.4.1 in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (1.7.3)
#
# Collecting lz4>=3.1.0
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [16 lines of output]
#   Using setuptools (version 61.2.0).
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.7\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.7\Box2D
#   creating build\lib.win-amd64-3.7\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.7\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [34 lines of output]
#   running bdist_wheel
#   running build
#   Traceback (most recent call last):
#     File "<string>", line 36, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\turbo\AppData\Local\Temp\pip-install-mvwea7td\mujoco-py_f72f8bc44e4d4e0997719510a0164092\setup.py", line 44, in <module>
#       tests_require=read_requirements_file('requirements.dev.txt'),
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#       return run_commands(dist)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#       dist.run_commands()
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#       super().run_command(command)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#       super().run_command(command)
#     File "C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "C:\Users\turbo\AppData\Local\Temp\pip-install-mvwea7td\mujoco-py_f72f8bc44e4d4e0997719510a0164092\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\turbo\AppData\Local\Temp\pip-install-mvwea7td\mujoco-py_f72f8bc44e4d4e0997719510a0164092\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\turbo\AppData\Local\Temp\pip-install-mvwea7td\mujoco-py_f72f8bc44e4d4e0997719510a0164092\mujoco_py\builder.py", line 20, in <module>
#       from lockfile import LockFile
#   ModuleNotFoundError: No module named 'lockfile'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mujoco-py
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   Running setup.py install for box2d-py did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Using setuptools (version 61.2.0).
#   running install
#   C:\Users\turbo\Anaconda3\lib\site-packages\setuptools\command\install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     setuptools.SetuptoolsDeprecationWarning,
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\Box2D
#   copying library\Box2D\Box2D.py -> build\lib.win-amd64-3.7\Box2D
#   copying library\Box2D\__init__.py -> build\lib.win-amd64-3.7\Box2D
#   creating build\lib.win-amd64-3.7\Box2D\b2
#   copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-3.7\Box2D\b2
#   running build_ext
#   building 'Box2D._Box2D' extension
#   Downloading lz4-4.0.2-cp37-cp37m-win_amd64.whl (98 kB)
#      ---------------------------------------- 98.9/98.9 kB 1.4 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      -------------------------------------- 374.4/374.4 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ale-py~=0.7.1 in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (0.7.4)
# Requirement already satisfied: opencv-python>=3. in c:\users\turbo\anaconda3\lib\site-packages (from gym[all]) (4.6.0.66)
# Collecting pyglet>=1.4.0
#   Downloading pyglet-1.5.26-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 7.2 MB/s eta 0:00:00
# Collecting mujoco-py<2.0,>=1.50
#   Downloading mujoco-py-1.50.1.68.tar.gz (120 kB)
#      -------------------------------------- 120.7/120.7 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-resources in c:\users\turbo\anaconda3\lib\site-packages (from ale-py~=0.7.1->gym[all]) (5.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\turbo\anaconda3\lib\site-packages (from importlib-metadata>=4.8.1->gym[all]) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\turbo\anaconda3\lib\site-packages (from importlib-metadata>=4.8.1->gym[all]) (4.3.0)
# Collecting glfw>=1.4.0
#   Downloading glfw-2.5.4-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-win_amd64.whl (492 kB)
#      -------------------------------------- 492.8/492.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: Cython>=0.27.2 in c:\users\turbo\anaconda3\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[all]) (0.29.30)
# Requirement already satisfied: imageio>=2.1.2 in c:\users\turbo\anaconda3\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[all]) (2.19.3)
# Requirement already satisfied: cffi>=1.10 in c:\users\turbo\anaconda3\lib\site-packages (from mujoco-py<2.0,>=1.50->gym[all]) (1.15.1)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: pycparser in c:\users\turbo\anaconda3\lib\site-packages (from cffi>=1.10->mujoco-py<2.0,>=1.50->gym[all]) (2.21)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\turbo\anaconda3\lib\site-packages (from imageio>=2.1.2->mujoco-py<2.0,>=1.50->gym[all]) (9.2.0)
# Building wheels for collected packages: box2d-py, mujoco-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
#   Building wheel for mujoco-py (setup.py): started
#   Building wheel for mujoco-py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco-py
# Failed to build box2d-py mujoco-py
# Installing collected packages: pyglet, lockfile, glfw, box2d-py, lz4, mujoco-py
#   Running setup.py install for box2d-py: started
#   Running setup.py install for box2d-py: finished with status 'error'
#   swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#   swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#   error: command 'swig.exe' failed: None
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# box2d-py
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\turbo\anaconda3\lib\site-packages)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
#env.close()
# Out:
# Episode:1 Score:13.0
# Episode:2 Score:23.0
# Episode:3 Score:13.0
# Episode:4 Score:55.0
# Episode:5 Score:11.0

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([ 9.0600860e-01,  2.4526216e+38,  1.2130527e-01, -1.9492759e+38],
#       dtype=float32)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 2207 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009235218 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00233    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.17        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 47.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008577649 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.0907      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 43.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008160524 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1135        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008714301 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 66.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009219551 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 58.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1088         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0064292313 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.85         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00782     |
# |    value_loss           | 49.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006295404 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 31.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005647338 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.08        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 10          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005143421 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 26.6        |
# -----------------------------------------

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\turbo\Anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (200.0, 0.0)

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
#env.close()
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[200.]
# Episode:4 Score:[200.]
# Episode:5 Score:[200.]

# %%
env.close()

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                            callback_on_new_best=stop_callback,
                            eval_freq=10000,
                            best_model_save_path=save_path,
                            verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 2242 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1408        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008453971 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00924    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.84        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 49          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1240         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0103432825 |
# |    clip_fraction        | 0.0825       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.666       |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0197      |
# |    value_loss           | 31.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009230086 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 45.5        |
# -----------------------------------------
# C:\Users\turbo\Anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0064750817 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 57.7         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 1534 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013536848 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.0205     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0152699575 |
# |    clip_fraction        | 0.192        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.432        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0312      |
# |    value_loss           | 28.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013073967 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 47          |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0074587194 |
# |    clip_fraction        | 0.0924       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0178      |
# |    value_loss           | 45.3         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 716   |
# |    iterations      | 5     |
# |    time_elapsed    | 14    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0090756025 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.53         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.99         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00925     |
# |    value_loss           | 33.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011449173 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6